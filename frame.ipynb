# %%
import cv2

# Load the video
video_path = r"C:\Users\ASUS\Downloads\ANPR - Copy (1)\ANPR - Copy\local333.mp4"
cap = cv2.VideoCapture(video_path)

# Check if the video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
else:
    # Get the frame rate (FPS)
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    print(f"Frame Rate (FPS): {fps}")
    print(f"total frames (total_frames): {total_frames}")

cap.release()
# Out:
# Frame Rate (FPS): 59.975036405242356
# total frames (total_frames): 961.0
